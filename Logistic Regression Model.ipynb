# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

raw_data = pd.read_csv('creditcard.csv')

x = raw_data[['Time','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18',
              'V19','V20','V21','V22','V23','V24','V25','V26','V27','V28','Amount']]

y = raw_data['Class']

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train, y_train)

print(model.coef_)

print(model.intercept_)

pd.DataFrame(model.coef_, x.columns, columns = ['Coeff'])

predictions = model.predict(x_test)

# plt.scatter(y_test, predictions)

plt.hist(y_test - predictions)

from sklearn import metrics

metrics.mean_absolute_error(y_test, predictions)

metrics.mean_squared_error(y_test, predictions)

np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# [-5.93697726e-09 -1.89272967e-03  3.01073586e-03 -5.09541228e-03
#   3.82356407e-03 -2.24537123e-03 -1.68378851e-03 -6.97098688e-03
#   6.96652772e-04 -3.64106722e-03 -8.11890788e-03  6.22777294e-03
#  -1.08558424e-02 -2.54559583e-04 -1.32675349e-02 -2.25297211e-04
#  -9.29324249e-03 -1.58843072e-02 -5.58497995e-03  1.99358653e-03
#   5.94959414e-05  1.96858732e-03  3.36005167e-04  2.15483808e-04
#  -5.09200760e-04  2.10809426e-04  4.09997496e-04  1.60135851e-03
#   8.68443298e-04  8.59962323e-06]
# 0.0015800640507935663
# 0.025796912022170413
